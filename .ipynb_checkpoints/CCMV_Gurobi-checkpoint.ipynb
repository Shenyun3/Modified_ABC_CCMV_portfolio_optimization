# %%
import numpy as np
import pandas as pd
import gurobipy as gb
import matplotlib.pyplot as plt

# %%
# read file
FILE_NAME = "/Users/bianhanzhang/Desktop/data/asset pool/SP500_100_assets_pool2.csv"
FILE_NAME2 ="/Users/bianhanzhang/Desktop/Coding/SP500_100_assets_pool2.csv" 
data = pd.read_csv(FILE_NAME2)
data.head(3)
# Out:
#    mean_return        MO       BLL      NTAP       AFL       AAP       SRE  \
# 0     0.001138  0.000102  0.000058  0.000071  0.000040  0.000037  0.000035
# 1    -0.000027  0.000058  0.000216  0.000172  0.000069  0.000120  0.000053
# 2     0.000937  0.000071  0.000172  0.000312  0.000080  0.000142  0.000044
#
#         MGM       DHI       AON  ...        LH      INCY       ALB      TROW  \
# 0  0.000049  0.000049  0.000062  ...  0.000053  0.000039  0.000043  0.000026
# 1  0.000093  0.000088  0.000180  ...  0.000102  0.000101  0.000072  0.000066
# 2  0.000112  0.000101  0.000198  ...  0.000120  0.000113  0.000081  0.000076
#
#         PFE        HP       BEN        EA       NSC       ECL
# 0  0.000030  0.000052  0.000043  0.000075  0.000048  0.000031
# 1  0.000041  0.000124  0.000082  0.000197  0.000118  0.000051
# 2  0.000011  0.000124  0.000098  0.000230  0.000114  0.000032
#
# [3 rows x 101 columns]

# %%
# mean return of 100 selected bonds
SP_mean_rtn = np.reshape(np.array(data.iloc[:,0]),(100,1))

# covariance of 100 selected bonds
SP_cov_rtn = np.array(data.iloc[:,1:])

# %%
def opt(rtn,cov,cardinality,n,min_po,max_po,risk_aversion_para):
    
    m = gb.Model()

    # variable
    weights = m.addMVar(n,lb=0,ub=1,name="weights")
    dv = m.addMVar(n,vtype = gb.GRB.BINARY,name="decision_variable")
    
    # model
    portfolio_return = gb.quicksum(weights[i] * rtn[i] for i in range(n))
    portfolio_risk = gb.quicksum(weights[i] * weights[j] * cov_rtn
                            for i in range(n)
                            for j in range(n)
                            for cov_rtn in [cov[i,j]])
    m.setObjective(risk_aversion_para * portfolio_risk - (1 - risk_aversion_para) * \
                   portfolio_return,gb.GRB.MINIMIZE)
    
    # weight constraint
    m.addConstr(weights.sum() == 1,"weights constraint")
#     # force x to be 0 if not selected
    m.addConstr(weights <= dv,"Indicator")
#     # holding position of one asset exceed minimum position
    m.addConstr(weights >= dv * min_po,"Minimum Position")
#     # holding position of one asset exceed maximum position
    m.addConstr(weights <= dv * max_po,"Maximum Position")
#     # Cardinality constraint
#     m.addConstr(dv.sum() == cardinality,"cardinality constraint")
    
    m.optimize()
    if m.status == gb.GRB.OPTIMAL:
        return weights.X,dv.X
    else:
        return None,None

# %%
# chromosome,dv = opt(SP_mean_rtn,SP_cov_rtn,15,100,0.001,0.40,0.5)

# %%
def cal_ann_return_risk(weight, mean_rtn, cov_rtn):
    """calculate annual return and risk"""
    ann_rtn = (1 + np.dot(weight, mean_rtn)) ** 252 - 1  # trading days: 252
    variance = (1 + np.dot(np.dot(weight, cov_rtn),weight.T)) ** 252 - 1
    ann_risk = np.sqrt(variance)            
    result = np.array([ann_rtn.item(),ann_risk])
    return result

# %%
def efficient_frontier(rtn,cov):
    ef_set = []

    # risk_aversion parameter
    risk_aversion_para = np.linspace(0.01,1,100)
    # cardinality
    cardinality = 15
    # dimension
    n = 100
    # minimum expected return
    min_return = 0.15
    # minimum position
    min_po = 0.001
    # maximum position
    max_po = 0.40
    
    for i in range(100):
        risk_para = risk_aversion_para[i]
        chromosome,dv = opt(rtn,cov,cardinality,n,min_po,max_po,risk_para)
        chromosome[dv == 0] = 0
        ef = cal_ann_return_risk(chromosome,rtn,cov)
        ef_set.append(ef)
    return ef_set

# %%
ucef_set = efficient_frontier(SP_mean_rtn,SP_cov_rtn)
# Out:
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.4.0 23E224)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 301 rows, 200 columns and 700 nonzeros
# Model fingerprint: 0x2c2b627c
# Model has 5050 quadratic objective terms
# Variable types: 100 continuous, 100 integer (100 binary)
# Coefficient statistics:
#   Matrix range     [1e-03, 1e+00]
#   Objective range  [3e-05, 2e-03]
#   QObjective range [5e-08, 1e-05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective -0.0005870
# Presolve removed 100 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 201 rows, 200 columns, 500 nonzeros
# Presolved model has 5050 quadratic objective terms
# Variable types: 100 continuous, 100 integer (100 binary)
#
# Root relaxation: objective -1.539679e-03, 47 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   -0.00154    0    1   -0.00059   -0.00154   162%     -    0s
# H    0     0                      -0.0015397   -0.00154  0.00%     -    0s
#      0     0   -0.00154    0    1   -0.00154   -0.00154  0.00%     -    0s
#
# Explored 1 nodes (47 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: -0.00153968 -0.000587001
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -1.539679278312e-03, best bound -1.539679278312e-03, gap 0.0000%
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.4.0 23E224)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 301 rows, 200 columns and 700 nonzeros
# Model fingerprint: 0x09af400e
# Model has 5050 quadratic objective terms
# Variable types: 100 continuous, 100 integer (100 binary)
# Coefficient statistics:
#   Matrix range     [1e-03, 1e+00]
#   Objective range  [3e-05, 2e-03]
#   QObjective range [9e-08, 2e-05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective -0.0005801
# Presolve removed 100 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 201 rows, 200 columns, 500 nonzeros
# Presolved model has 5050 quadratic objective terms
# Variable types: 100 continuous, 100 integer (100 binary)
#
# Root relaxation: objective -1.522476e-03, 27 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   -0.00152    0    1   -0.00058   -0.00152   162%     -    0s
# H    0     0                      -0.0015225   -0.00152  0.00%     -    0s
#      0     0   -0.00152    0    1   -0.00152   -0.00152  0.00%     -    0s
#
# Explored 1 nodes (27 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: -0.00152248 -0.000580053
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -1.522476186308e-03, best bound -1.522476186308e-03, gap 0.0000%
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.4.0 23E224)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 301 rows, 200 columns and 700 nonzeros
# Model fingerprint: 0xdb81114a
# Model has 5050 quadratic objective terms
# Variable types: 100 continuous, 100 integer (100 binary)
# Coefficient statistics:
#   Matrix range     [1e-03, 1e+00]
#   Objective range  [3e-05, 2e-03]
#   QObjective range [1e-07, 4e-05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective -0.0005731
# Presolve removed 100 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 201 rows, 200 columns, 500 nonzeros
# Presolved model has 5050 quadratic objective terms
# Variable types: 100 continuous, 100 integer (100 binary)
#
# Root relaxation: objective -1.505273e-03, 47 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   -0.00151    0    1   -0.00057   -0.00151   163%     -    0s
# H    0     0                      -0.0015053   -0.00151  0.00%     -    0s
#      0     0   -0.00151    0    1   -0.00151   -0.00151  0.00%     -    0s
#
# Explored 1 nodes (47 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: -0.00150527 -0.000573104
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -1.505273094305e-03, best bound -1.505273094305e-03, gap 0.0000%
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.4.0 23E224)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 301 rows, 200 columns and 700 nonzeros
# Model fingerprint: 0x4ed6124c
# Model has 5050 quadratic objective terms
# Variable types: 100 continuous, 100 integer (100 binary)
# Coefficient statistics:
#   Matrix range     [1e-03, 1e+00]
#   Objective range  [3e-05, 2e-03]
#   QObjective range [2e-07, 5e-05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective -0.0005662
# Presolve removed 100 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 201 rows, 200 columns, 500 nonzeros
# Presolved model has 5050 quadratic objective terms
# Variable types: 100 continuous, 100 integer (100 binary)
#
# Root relaxation: objective -1.488070e-03, 47 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   -0.00149    0    1   -0.00057   -0.00149   163%     -    0s
# H    0     0                      -0.0014881   -0.00149  0.00%     -    0s
#      0     0   -0.00149    0    1   -0.00149   -0.00149  0.00%     -    0s
#
# Explored 1 nodes (47 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: -0.00148807 -0.000566155
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -1.488070002301e-03, best bound -1.488070002301e-03, gap 0.0000%
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.4.0 23E224)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 301 rows, 200 columns and 700 nonzeros
# Model fingerprint: 0xe70fec7a
# Model has 5050 quadratic objective terms
# Variable types: 100 continuous, 100 integer (100 binary)
# Coefficient statistics:
#   Matrix range     [1e-03, 1e+00]
#   Objective range  [3e-05, 2e-03]
#   QObjective range [2e-07, 6e-05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective -0.0005592
# Presolve removed 100 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 201 rows, 200 columns, 500 nonzeros
# Presolved model has 5050 quadratic objective terms
# Variable types: 100 continuous, 100 integer (100 binary)
#
# Root relaxation: objective -1.470867e-03, 41 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   -0.00147    0    1   -0.00056   -0.00147   163%     -    0s
# H    0     0                      -0.0014709   -0.00147  0.00%     -    0s
#      0     0   -0.00147    0    1   -0.00147   -0.00147  0.00%     -    0s
#
# Explored 1 nodes (41 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: -0.00147087 -0.000559206
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -1.470866910297e-03, best bound -1.470866910297e-03, gap 0.0000%
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.4.0 23E224)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 301 rows, 200 columns and 700 nonzeros
# Model fingerprint: 0x76f314ae
# Model has 5050 quadratic objective terms
# Variable types: 100 continuous, 100 integer (100 binary)
# Coefficient statistics:
#   Matrix range     [1e-03, 1e+00]
#   Objective range  [3e-05, 2e-03]
#   QObjective range [3e-07, 7e-05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective -0.0005523
# Presolve removed 100 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 201 rows, 200 columns, 500 nonzeros
# Presolved model has 5050 quadratic objective terms
# Variable types: 100 continuous, 100 integer (100 binary)
#
# Root relaxation: objective -1.453664e-03, 37 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   -0.00145    0    1   -0.00055   -0.00145   163%     -    0s
# H    0     0                      -0.0014537   -0.00145  0.00%     -    0s
#      0     0   -0.00145    0    1   -0.00145   -0.00145  0.00%     -    0s
#
# Explored 1 nodes (37 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: -0.00145366 -0.000552257
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -1.453663818293e-03, best bound -1.453663818293e-03, gap 0.0000%
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.4.0 23E224)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 301 rows, 200 columns and 700 nonzeros
# Model fingerprint: 0xd965ef67
# Model has 5050 quadratic objective terms
# Variable types: 100 continuous, 100 integer (100 binary)
# Coefficient statistics:
#   Matrix range     [1e-03, 1e+00]
#   Objective range  [3e-05, 2e-03]
#   QObjective range [3e-07, 8e-05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective -0.0005453
# Presolve removed 100 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 201 rows, 200 columns, 500 nonzeros
# Presolved model has 5050 quadratic objective terms
# Variable types: 100 continuous, 100 integer (100 binary)
#
# Root relaxation: objective -1.436461e-03, 38 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   -0.00144    0    1   -0.00055   -0.00144   163%     -    0s
# H    0     0                      -0.0014365   -0.00144  0.00%     -    0s
#      0     0   -0.00144    0    1   -0.00144   -0.00144  0.00%     -    0s
#
# Explored 1 nodes (38 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: -0.00143646 -0.000545309
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -1.436460726289e-03, best bound -1.436460726289e-03, gap 0.0000%
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.4.0 23E224)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 301 rows, 200 columns and 700 nonzeros
# Model fingerprint: 0x4adef28d
# Model has 5050 quadratic objective terms
# Variable types: 100 continuous, 100 integer (100 binary)
# Coefficient statistics:
#   Matrix range     [1e-03, 1e+00]
#   Objective range  [2e-05, 2e-03]
#   QObjective range [4e-07, 1e-04]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective -0.0005384
# Presolve removed 100 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 201 rows, 200 columns, 500 nonzeros
# Presolved model has 5050 quadratic objective terms
# Variable types: 100 continuous, 100 integer (100 binary)
#
# Root relaxation: objective -1.419258e-03, 27 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   -0.00142    0    1   -0.00054   -0.00142   164%     -    0s
# H    0     0                      -0.0014193   -0.00142  0.00%     -    0s
#      0     0   -0.00142    0    1   -0.00142   -0.00142  0.00%     -    0s
#
# Explored 1 nodes (27 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: -0.00141926 -0.00053836
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -1.419257634285e-03, best bound -1.419257634285e-03, gap 0.0000%
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.4.0 23E224)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 301 rows, 200 columns and 700 nonzeros
# Model fingerprint: 0
0.00%     -    0s
#
# Cutting planes:
#   MIR: 1
#   Flow cover: 1
#
# Explored 1 nodes (95 simplex iterations) in 0.01 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 5: 2.68643e-05 3.08247e-05 3.21791e-05 ... 8.70326e-05
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.686427994525e-05, best bound 2.686427994525e-05, gap 0.0000%
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.4.0 23E224)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 301 rows, 200 columns and 700 nonzeros
# Model fingerprint: 0x86095097
# Model has 5050 quadratic objective terms
# Variable types: 100 continuous, 100 integer (100 binary)
# Coefficient statistics:
#   Matrix range     [1e-03, 1e+00]
#   Objective range  [3e-07, 2e-05]
#   QObjective range [5e-06, 1e-03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 0.0000940
# Presolve removed 100 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 201 rows, 200 columns, 500 nonzeros
# Presolved model has 5050 quadratic objective terms
# Variable types: 100 continuous, 100 integer (100 binary)
#
# Root relaxation: objective 3.414952e-05, 136 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.00003    0   31    0.00009    0.00003  63.7%     -    0s
# H    0     0                       0.0000341    0.00003  0.00%     -    0s
#      0     0    0.00003    0   31    0.00003    0.00003  0.00%     -    0s
#
# Explored 1 nodes (136 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 3.41496e-05 9.39814e-05
#
# Optimal solution found (tolerance 1.00e-04)
# Warning: max integrality violation (1.2613e-05) exceeds tolerance
# Best objective 3.414960160724e-05, best bound 3.414960160724e-05, gap 0.0000%
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.4.0 23E224)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 301 rows, 200 columns and 700 nonzeros
# Model fingerprint: 0x44c4eda1
# Model has 5050 quadratic objective terms
# Variable types: 100 continuous, 100 integer (100 binary)
# Coefficient statistics:
#   Matrix range     [1e-03, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   QObjective range [5e-06, 1e-03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 0.0001009
# Presolve removed 100 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 201 rows, 200 columns, 500 nonzeros
# Presolved model has 5050 quadratic objective terms
# Variable types: 100 continuous, 100 integer (100 binary)
#
# Root relaxation: objective 3.996265e-05, 106 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.00004    0   34    0.00010    0.00004  60.4%     -    0s
# H    0     0                       0.0000400    0.00004  0.00%     -    0s
#      0     0    0.00004    0   34    0.00004    0.00004  0.00%     -    0s
#
# Explored 1 nodes (106 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 3.99627e-05 0.00010093
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.996267260656e-05, best bound 3.996267260656e-05, gap 0.0000%

# %%
draw_ef(ucef_set)

# %%
ef_set = efficient_frontier(SP_mean_rtn,SP_cov_rtn)
# Out:
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.4.0 23E224)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 302 rows, 200 columns and 800 nonzeros
# Model fingerprint: 0xdf3a6aea
# Model has 5050 quadratic objective terms
# Variable types: 100 continuous, 100 integer (100 binary)
# Coefficient statistics:
#   Matrix range     [1e-03, 1e+00]
#   Objective range  [3e-05, 2e-03]
#   QObjective range [5e-08, 1e-05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective -0.0004617
# Presolve removed 100 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 202 rows, 200 columns, 600 nonzeros
# Presolved model has 5050 quadratic objective terms
# Variable types: 100 continuous, 100 integer (100 binary)
#
# Root relaxation: objective -1.529742e-03, 438 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                      -0.0005116   -0.00153   199%     -    0s
# *    0     0               0      -0.0015297   -0.00153  0.00%     -    0s
#
# Explored 1 nodes (438 simplex iterations) in 0.01 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: -0.00152974 -0.000511647 -0.00046173
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -1.529742297938e-03, best bound -1.529742297938e-03, gap 0.0000%
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.4.0 23E224)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 302 rows, 200 columns and 800 nonzeros
# Model fingerprint: 0xf65c82ed
# Model has 5050 quadratic objective terms
# Variable types: 100 continuous, 100 integer (100 binary)
# Coefficient statistics:
#   Matrix range     [1e-03, 1e+00]
#   Objective range  [3e-05, 2e-03]
#   QObjective range [9e-08, 2e-05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective -0.0004553
# Presolve removed 100 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 202 rows, 200 columns, 600 nonzeros
# Presolved model has 5050 quadratic objective terms
# Variable types: 100 continuous, 100 integer (100 binary)
#
# Root relaxation: objective -1.514777e-03, 468 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                      -0.0005054   -0.00151   200%     -    0s
# *    0     0               0      -0.0015148   -0.00151  0.00%     -    0s
#
# Explored 1 nodes (468 simplex iterations) in 0.01 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: -0.00151478 -0.000505426 -0.00045529
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -1.514776927918e-03, best bound -1.514776927918e-03, gap 0.0000%
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.4.0 23E224)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 302 rows, 200 columns and 800 nonzeros
# Model fingerprint: 0x4199b3f7
# Model has 5050 quadratic objective terms
# Variable types: 100 continuous, 100 integer (100 binary)
# Coefficient statistics:
#   Matrix range     [1e-03, 1e+00]
#   Objective range  [3e-05, 2e-03]
#   QObjective range [1e-07, 4e-05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective -0.0004489
# Presolve removed 100 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 202 rows, 200 columns, 600 nonzeros
# Presolved model has 5050 quadratic objective terms
# Variable types: 100 continuous, 100 integer (100 binary)
#
# Root relaxation: objective -1.495200e-03, 438 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                      -0.0004992   -0.00150   200%     -    0s
# *    0     0               0      -0.0014952   -0.00150  0.00%     -    0s
#
# Explored 1 nodes (438 simplex iterations) in 0.01 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: -0.0014952 -0.000499205 -0.000448851
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -1.495199734676e-03, best bound -1.495199734676e-03, gap 0.0000%
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.4.0 23E224)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 302 rows, 200 columns and 800 nonzeros
# Model fingerprint: 0x5deba330
# Model has 5050 quadratic objective terms
# Variable types: 100 continuous, 100 integer (100 binary)
# Coefficient statistics:
#   Matrix range     [1e-03, 1e+00]
#   Objective range  [3e-05, 2e-03]
#   QObjective range [2e-07, 5e-05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective -0.0004424
# Presolve removed 100 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 202 rows, 200 columns, 600 nonzeros
# Presolved model has 5050 quadratic objective terms
# Variable types: 100 continuous, 100 integer (100 binary)
#
# Root relaxation: objective -1.478495e-03, 438 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                      -0.0004930   -0.00148   200%     -    0s
# *    0     0               0      -0.0014785   -0.00148  0.00%     -    0s
#
# Explored 1 nodes (438 simplex iterations) in 0.01 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: -0.00147849 -0.000492984 -0.000442412
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -1.478494538947e-03, best bound -1.478494538947e-03, gap 0.0000%
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.4.0 23E224)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 302 rows, 200 columns and 800 nonzeros
# Model fingerprint: 0x93374985
# Model has 5050 quadratic objective terms
# Variable types: 100 continuous, 100 integer (100 binary)
# Coefficient statistics:
#   Matrix range     [1e-03, 1e+00]
#   Objective range  [3e-05, 2e-03]
#   QObjective range [2e-07, 6e-05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective -0.0004360
# Presolve removed 100 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 202 rows, 200 columns, 600 nonzeros
# Presolved model has 5050 quadratic objective terms
# Variable types: 100 continuous, 100 integer (100 binary)
#
# Root relaxation: objective -1.461412e-03, 438 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                      -0.0004868   -0.00146   200%     -    0s
# *    0     0               0      -0.0014614   -0.00146  0.00%     -    0s
#
# Explored 1 nodes (438 simplex iterations) in 0.01 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: -0.00146141 -0.000486763 -0.000435973
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -1.461411952617e-03, best bound -1.461411952617e-03, gap 0.0000%
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.4.0 23E224)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 302 rows, 200 columns and 800 nonzeros
# Model fingerprint: 0x0d4d9e80
# Model has 5050 quadratic objective terms
# Variable types: 100 continuous, 100 integer (100 binary)
# Coefficient statistics:
#   Matrix range     [1e-03, 1e+00]
#   Objective range  [3e-05, 2e-03]
#   QObjective range [3e-07, 7e-05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective -0.0004295
# Presolve removed 100 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 202 rows, 200 columns, 600 nonzeros
# Presolved model has 5050 quadratic objective terms
# Variable types: 100 continuous, 100 integer (100 binary)
#
# Root relaxation: objective -1.444682e-03, 444 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                      -0.0004805   -0.00144   201%     -    0s
# *    0     0               0      -0.0014447   -0.00144  0.00%     -    0s
#
# Explored 1 nodes (444 simplex iterations) in 0.01 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: -0.00144468 -0.000480542 -0.000429534
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -1.444682325853e-03, best bound -1.444682325853e-03, gap 0.0000%
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.4.0 23E224)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 302 rows, 200 columns and 800 nonzeros
# Model fingerprint: 0x9fae438f
# Model has 5050 quadratic objective terms
# Variable types: 100 continuous, 100 integer (100 binary)
# Coefficient statistics:
#   Matrix range     [1e-03, 1e+00]
#   Objective range  [3e-05, 2e-03]
#   QObjective range [3e-07, 8e-05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective -0.0004231
# Presolve removed 100 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 202 rows, 200 columns, 600 nonzeros
# Presolved model has 5050 quadratic objective terms
# Variable types: 100 continuous, 100 integer (100 binary)
#
# Root relaxation: objective -1.427596e-03, 444 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                      -0.0004743   -0.00143   201%     -    0s
# *    0     0               0      -0.0014276   -0.00143  0.00%     -    0s
#
# Explored 1 nodes (444 simplex iterations) in 0.01 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: -0.0014276 -0.000474321 -0.000423095
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -1.427595632922e-03, best bound -1.427595632922e-03, gap 0.0000%
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.4.0 23E224)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 302 rows, 200 columns and 800 nonzeros
# Model fingerprint: 0x764b04ec
# Model has 5050 quadratic objective terms
# Variable types: 100 continuous, 100 integer (100 binary)
# Coefficient statistics:
#   Matrix range     [1e-03, 1e+00]
#   Objective range  [2e-05, 2e-03]
#   QObjective range [4e-07, 1e-04]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective -0.0004167
# Presolve removed 100 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 202 rows, 200 columns, 600 nonzeros
# Presolved model has 5050 quadratic objective terms
# Variable types: 100 continuous, 100 integer (100 binary)
#
# Root relaxation: objective -1.410723e-03, 450 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                      -0.0004681   -0.00141   201%     -    0s
# *    0     0               0      -0.0014107   -0.00141  0.00%     -    0s
#
# Explored 1 nodes (450 simplex iterations) in 0.01 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: -0.
simplex iterations) in 0.02 seconds (0.02 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 7: 2.70565e-05 2.97037e-05 3.02587e-05 ... 0.00016287
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.705651740094e-05, best bound 2.705651740094e-05, gap 0.0000%
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.4.0 23E224)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 302 rows, 200 columns and 800 nonzeros
# Model fingerprint: 0x17d53614
# Model has 5050 quadratic objective terms
# Variable types: 100 continuous, 100 integer (100 binary)
# Coefficient statistics:
#   Matrix range     [1e-03, 1e+00]
#   Objective range  [3e-07, 2e-05]
#   QObjective range [5e-06, 1e-03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 0.0001693
# Presolve removed 100 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 202 rows, 200 columns, 600 nonzeros
# Presolved model has 5050 quadratic objective terms
# Variable types: 100 continuous, 100 integer (100 binary)
#
# Root relaxation: objective 3.425577e-05, 493 iterations, 0.00 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                       0.0000980    0.00003  65.1%     -    0s
#      0     0    0.00003    0   20    0.00010    0.00003  65.1%     -    0s
# H    0     0                       0.0000390    0.00003  12.2%     -    0s
# H    0     0                       0.0000388    0.00003  11.6%     -    0s
# H    0     0                       0.0000374    0.00003  8.53%     -    0s
#      0     0    0.00003    0   20    0.00004    0.00003  8.17%     -    0s
# H    0     0                       0.0000346    0.00003  0.68%     -    0s
# H    0     0                       0.0000346    0.00003  0.54%     -    0s
#      0     2    0.00003    0   20    0.00003    0.00003  0.54%     -    0s
# H  515   185                       0.0000346    0.00003  0.52%  10.2    0s
#
# Explored 40730 nodes (313973 simplex iterations) in 1.85 seconds (3.99 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 8: 3.45678e-05 3.45746e-05 3.4623e-05 ... 0.000169309
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.456784429323e-05, best bound 3.456784429323e-05, gap 0.0000%
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.4.0 23E224)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 302 rows, 200 columns and 800 nonzeros
# Model fingerprint: 0xb7c26b5b
# Model has 5050 quadratic objective terms
# Variable types: 100 continuous, 100 integer (100 binary)
# Coefficient statistics:
#   Matrix range     [1e-03, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   QObjective range [5e-06, 1e-03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 0.0001757
# Presolve removed 100 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 202 rows, 200 columns, 600 nonzeros
# Presolved model has 5050 quadratic objective terms
# Variable types: 100 continuous, 100 integer (100 binary)
#
# Root relaxation: objective 4.017891e-05, 155 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                       0.0001042    0.00004  61.5%     -    0s
#      0     0    0.00004    0   24    0.00010    0.00004  61.5%     -    0s
# H    0     0                       0.0000479    0.00004  16.1%     -    0s
# H    0     0                       0.0000454    0.00004  11.6%     -    0s
# H    0     0                       0.0000454    0.00004  11.4%     -    0s
#      0     0    0.00004    0   24    0.00005    0.00004  11.4%     -    0s
#      0     0    0.00004    0   24    0.00005    0.00004  11.3%     -    0s
# H    0     0                       0.0000404    0.00004  0.51%     -    0s
#      0     2    0.00004    0   21    0.00004    0.00004  0.51%     -    0s
#
# Explored 19939 nodes (192029 simplex iterations) in 1.20 seconds (2.41 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 7: 4.04326e-05 4.53728e-05 4.54381e-05 ... 0.000175749
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.043263891586e-05, best bound 4.043263891586e-05, gap 0.0000%

# %%
print(f"Solution time:    {m.Runtime:.4f} seconds\n")
# Out:
# Solution time:    0.0187 seconds

# %%
def draw_ef(ef_set):
    """
    绘制效率前沿图。
    
    参数:
    ef_set (list of lists): 每个元素是一个包含[收益, 风险]的列表。
    """
    # 分解 ef_set 列表以获取单独的收益和风险列表
    returns = [item[0] for item in ef_set]
    risks = [item[1] for item in ef_set]

    # 创建图形和坐标轴
    fig, ax = plt.subplots()

    # 绘制风险和收益点
    ax.plot(risks, returns, 'o-', label='Efficient Frontier')  # 使用圆点和线连接的方式绘制

    # 设置图形的标题和坐标轴的标签
    ax.set_title('Efficient Frontier')
    ax.set_xlabel('Risk (Standard Deviation)')
    ax.set_ylabel('Expected Return')

    # 添加图例
    ax.legend()

    # 启用网格
    ax.grid(True)

    # 显示图形
    plt.show()

# %%
# ef_set

# %%
draw_ef(ef_set)

# %% [markdown]
# <img src="measurement.png" alt="measurement" style="float:left; height:400px; width:auto; border:1px solid black">

# %%
def difference(ucef,ccef):
    diff = 0
    x_diff_set = []
    y_diff_set = []

    sorted_ucef = np.array(sorted(ucef, key=lambda x: x[0]))
    sorted_ucef2 = np.array(sorted(ucef, key=lambda x: x[1]))
    y_values = sorted_ucef2[:, 1].astype(float)
    

    # 遍历第二个数组中的每个元素
    for a, b in ccef:
        
        # xj and yj_alt / xk and yk_alt
        # 二分查找大于a的最小x
        idx = np.searchsorted(sorted_ucef[:, 0], a, side='right')

        # 获取大于a的最小x及其对应的y
        if idx < len(sorted_ucef):
            xj, yj_alt = sorted_ucef[idx]
        else:
            xj, yj = a, b  # 如果不存在，返回None

        # 二分查找小于a的最大x
        idx_k = idx - 1

        # 获取小于a的最大x及其对应的y
        if idx_k >= 0:
            xk, yk_alt = sorted_ucef[idx_k]
        else:
            xk, yk_alt = a, b  # 如果不存在，返回None
            
            
        # yj xj_alt and yk xk_alt
            
        idx = np.searchsorted(y_values, b, side='right')
        
        # 获取大于 bi 的最小 y 及其对应的 x
        if idx < len(sorted_ucef2):
            xj_alt, yj = sorted_ucef2[idx]
        else:
            xj_alt, yj = a, b  # 如果不存在，返回 None
        
        # 二分查找小于 bi 的最大 y
        idx_k = idx - 1
        
        # 获取小于 bi 的最大 y 及其对应的 x
        if idx_k >= 0:
            xk_alt, yk = sorted_ucef2[idx_k]
        else:
            xk_alt, yk = a, b  # 如果不存在，返回 None
        
        # y* : item[0] x* : item[1]
        
        x_ss = xk_alt + (xj_alt - xk_alt)*(a - yk)/(yj - yk)
        y_ss = yk_alt + (yj_alt - yk_alt)*(b - xk)/(xj - xk)
        
        x_diff = abs(100 * (b - x_ss)/x_ss)
        y_diff = abs(100 * (np.sqrt(a) - np.sqrt(y_ss))/y_ss)
        
        x_diff_set.append(x_diff)
        y_diff_set.append(y_diff)
    
    return x_diff_set,y_diff_set

# %%
ucef = [[5, 7], [7, 9], [12, 20], [14, 25]]
ccef = [[5, 6], [6, 10],[13,18],[15,23]]
x,y = difference(ucef,ccef)

# %%
# %store -r ef_set

# %%
x,y = difference(ucef_set,ef_set)

# %%
def measurement(x_diff,y_diff):
    """
    Calculate measurement
    x_diff:risk_diff:standard deciation
    y_diff:return_diff
    """
    MEAPE = 0
    MEDPE = 0
    MINPE = 0
    MAXPE = 0
    for x,y in zip(x_diff,y_diff):
        MEAPE += min(x,y)
    MEAPE/=len(x_diff)
    MEDPE = min(np.median(x_diff),np.median(y_diff))
    MINPE = min(min(x_diff),min(y_diff))
    MAXPE = max(max(x_diff),max(y_diff))

    return MEAPE,MEDPE,MINPE,MAXPE

# %%
MEAPE,MEDPE,MINPE,MAXPE = measurement(x,y)
print(f"MEAPE:{MEAPE}")
print(f"MEDPE:{MEDPE}")
print(f"MINPE:{MINPE}")
print(f"MAXPE:{MAXPE}")
# Out:
# MEAPE:80.22590139542584
# MEDPE:72.46527180458006
# MINPE:2.0234565987741453
# MAXPE:659.3689974426
